# %% [markdown]
# ## CHINNA PASHULA BHANU PRAKASH REDDY

# %% [markdown]
# ### TASK 1

# %% [markdown]
# ### Q1)
# <img src="attachment:a9f3797c-a72c-4bcf-ad4f-d044421bb4da.png" width="600">

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### Q2
# <img src="attachment:acb8ef3f-9434-42b0-aacb-221cd2b889a6.png" width="500">
# <img src="attachment:1ca824a9-019e-452e-b08a-e31f9a27b258.png" width="500">

# %%
n = int(input())
if n % 2 != 0:
    print("Weird")
else:
    if 2 <= n <= 5:
        print("Not Weird")
    elif 6 <= n <= 20:
        print("Weird")
    else:
        print("Not Weird")
# Out:
#  15
# Weird

# %% [markdown]
# ### Q3)
# <img src="attachment:60f13dd0-59d0-49aa-ba36-8116b66c73c6.png" width="900">

# %%
a = int(input())
b = int(input())

print(a // b)
print(a / b)
# Out:
#  10
#  5
# 2
# 2.0

# %% [markdown]
# ### Q4)
# <img src="attachment:b26f20d7-de1a-4ad2-97b0-71f10965ef3a.png" width="700">

# %%
a = int(input())
b = int(input())

print(a + b)
print(a - b)
print(a * b)
# Out:
#  10
#  5
# 15
# 5
# 50

# %% [markdown]
# ### Q5)
# <img src="attachment:b0de3ca5-c441-48b3-91fe-b4322de87f26.png" width="700">

# %%
n = int(input())

for i in range(n):
    print(i * i)
# Out:
#  5
# 0
# 1
# 4
# 9
# 16

# %% [markdown]
# ### Q6)
# <img src="attachment:007fd7f9-db4a-4790-9d60-a02c8290b3b9.png" width="700">

# %%
def is_leap(year):
    if year % 4 != 0:
        return False
    elif year % 100 != 0:
        return True
    elif year % 400 == 0:
        return True
    else:
        return False
print(is_leap(int(input())))
# Out:
#  2025
# False

# %% [markdown]
# ### Q7)
# <img src="attachment:098096a0-f8ec-4a1d-a49c-a22204b45b58.png" width="600">

# %%
n = int(input())
s = ""
for i in range(1,n+1):
    s += str(i)
print(s)
# Out:
#  10
# 12345678910
